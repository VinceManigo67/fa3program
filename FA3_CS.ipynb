# %% [markdown]
# <a href="https://colab.research.google.com/github/VinceManigo67/fa3program/blob/main/FA3_CS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1
name = input("Enter your name: ")
age = int(input("Enter your age: "))
course = input("Enter your course: ")

print("name:", name)
print("age:", age)
print("course:", course)

# %%
#fa3prog2
score = int(input("Enter your exam score (0-100): "))

if 0 <= score <= 100:
  print("Your exam score is:", score)
else:
  print("Invalid score. Please enter a score between 0 and 100.")

if score >= 75:
        print("Passed")
else:
     print("Failed")

# %%
#fa3prog3
name = input("Enter your name: ")
score = int(input("Enter your exam score (0-100): "))

if 0 <= score <= 100:
  print("Your exam score is:", score)
else:
  print("Invalid score. Please enter a score between 0 and 100.")

if score >= 90 and score <= 100:
  print("Your grade is: A")
  print("Excellent performance!", name)
elif score >= 80 and score <= 89:
  print("Your grade is: B")
  print("Good performance!", name)
elif score >= 70 and score <= 79:
  print("Your grade is: C")
  print("Decent performance!", name)
else:
  print("Your grade is: F")
  print("Needs improvement, but  nice try!", name)
